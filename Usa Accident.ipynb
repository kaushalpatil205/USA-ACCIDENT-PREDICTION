# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\kunal  kumar  pandey\Downloads\US_Accidents_Dec21_updated[1].csv")

# %%
data.head(5)
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
data.tail(5)
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 2845337  A-2845338         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat  Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# 2845337   34.00248 -117.37936  33.99888 -117.37094         0.543
# 2845338   32.76696 -117.14806  32.76555 -117.15363         0.338
# 2845339   33.77545 -117.84779  33.77740 -117.85727         0.561
# 2845340   33.99246 -118.40302  33.98311 -118.39565         0.772
# 2845341   34.13393 -117.23092  34.13736 -117.23934         0.537
#
#                                                Description  ...  Roundabout  \
# ...

# %%
data.shape
# Out:
# (2845342, 47)

# %%
data.size
# Out:
# 133731074

# %%
data.keys()
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
data.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
data.isnull().sum().sort_values()
# Out:
# ID                             0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Country                        0
# Amenity                        0
# State                          0
# End_Lng                        0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# County                         0
# Bump                           0
# Description                    0
# Side                           0
# Distance(mi)                   0
# Street                         2
# ...

# %%
#count numeric data column
numerics=['int16','int32','int64','float16','float32','float64']
numeric_df=data.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %%
# import label encoder
from sklearn import preprocessing
# label_encoder object knows how to understand word labels
label_encoder=preprocessing.LabelEncoder()

# %%
#encodes label in columns 'species'
data['Start_Time']=label_encoder.fit_transform(data['Start_Time'])
data['End_Time']=label_encoder.fit_transform(data['End_Time'])
data['Description']=label_encoder.fit_transform(data['Description'])
data['Side']=label_encoder.fit_transform(data['Side'])
data['Zipcode']=label_encoder.fit_transform(data['Zipcode'])
data['City']=label_encoder.fit_transform(data['City'])
data['Timezone']=label_encoder.fit_transform(data['Timezone'])
data['Wind_Direction']=label_encoder.fit_transform(data['Wind_Direction'])
data['Weather_Condition']=label_encoder.fit_transform(data['Weather_Condition'])
data['Sunrise_Sunset']=label_encoder.fit_transform(data['Sunrise_Sunset'])
data['Civil_Twilight']=label_encoder.fit_transform(data['Civil_Twilight'])
data['Nautical_Twilight']=label_encoder.fit_transform(data['Nautical_Twilight'])
data['Astronomical_Twilight']=label_encoder.fit_transform(data['Astronomical_Twilight'])

data['Start_Time'].unique()
data['End_Time'].unique()
data['Description'].unique()
data['Side'].unique()
data['Zipcode'].unique()
data['City'].unique()
data['Timezone'].unique()
data['Wind_Direction'].unique()
data['Weather_Condition'].unique()
data['Sunrise_Sunset'].unique()
data['Civil_Twilight'].unique()
data['Nautical_Twilight'].unique()
data['Astronomical_Twilight'].unique()
# Out:
# array([1, 0, 2])

# %%
data.dtypes
# Out:
# ID                        object
# Severity                   int64
# Start_Time                 int32
# End_Time                   int32
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description                int32
# Number                   float64
# Street                    object
# Side                       int32
# City                       int32
# County                    object
# State                     object
# Zipcode                    int32
# Country                   object
# Timezone                   int32
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction             int32
# Wind_Speed(mph)          float64
# ...

# %%
#convert float to integer
data['Start_Lat']=label_encoder.fit_transform(data['Start_Lat'])
data['Start_Lng']=label_encoder.fit_transform(data['Start_Lng'])
data['Distance(mi)']=label_encoder.fit_transform(data['Distance(mi)'])
data['Number']=label_encoder.fit_transform(data['Number'])
data['Temperature(F)']=label_encoder.fit_transform(data['Temperature(F)'])
data['Pressure(in)']=label_encoder.fit_transform(data['Pressure(in)'])
data['Wind_Speed(mph)']=label_encoder.fit_transform(data['Wind_Speed(mph)'])

data['Start_Lat'].unique()
data['Start_Lng'].unique()
data['Distance(mi)'].unique()
data['Number'].unique()
data['Temperature(F)'].unique()
data['Pressure(in)'].unique()
data['Wind_Speed(mph)'].unique()
# Out:
# array([ 18, 136,  14,   4,   6,  19,   7,   9,  27,  23,  16,  25,  15,
#         21,  32,  29,  47,  31,  11,  44,  36,  22,  38,  34,  12,  40,
#         49,  56,  45,  42,   0,  10,  52,   2,  54,  65,  26,  33,  30,
#          5,  13,  20,   8,  17,  61,  24,  57, 105, 133,  79,  67,  81,
#         72,  69,  63,  92,  59,   3,  28,  35,  37, 100,  70,  41,  39,
#         48, 112,  82,  50, 111,  76,  43,  90,  58, 122, 101, 130,  46,
#         84,  53, 124,   1,  60,  75,  64,  51,  55, 114,  78, 102,  66,
#         62,  93,  85,  71,  68,  86,  73,  87,  77,  98, 117,  99, 110,
#         80,  83,  91, 113, 132, 125, 106, 121,  97, 128, 135, 109, 107,
#         89, 103, 115, 126, 127, 116,  96, 134,  95, 131, 123,  88,  74,
#         94, 108, 104, 129, 118, 119, 120], dtype=int64)

# %%
#convert 'playoffs' column to integer
data.Traffic_Signal= data.Traffic_Signal.replace({True: 1, False: 0})
data.Amenity=data.Amenity.replace({True: 1, False: 0})
data.No_Exit= data.No_Exit.replace({True: 1, False: 0})
data.Junction=data.Junction.replace({True: 1, False: 0})

# %%
#count numeric data column
numerics=['int16','int32','int64','float16','float32','float64']
numeric_df=data.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 31

# %%
Traffic=data['Traffic_Signal']==0
Traffic.tail(15)
# Out:
# 2845327    True
# 2845328    True
# 2845329    True
# 2845330    True
# 2845331    True
# 2845332    True
# 2845333    True
# 2845334    True
# 2845335    True
# 2845336    True
# 2845337    True
# 2845338    True
# 2845339    True
# 2845340    True
# 2845341    True
# Name: Traffic_Signal, dtype: bool

# %%
data.Traffic_Signal.tail(25)
# Out:
# 2845317    0
# 2845318    0
# 2845319    0
# 2845320    0
# 2845321    0
# 2845322    0
# 2845323    0
# 2845324    0
# 2845325    0
# 2845326    0
# 2845327    0
# 2845328    0
# 2845329    0
# 2845330    0
# 2845331    0
# 2845332    0
# 2845333    0
# 2845334    0
# 2845335    0
# 2845336    0
# 2845337    0
# 2845338    0
# 2845339    0
# 2845340    0
# 2845341    0
# Name: Traffic_Signal, dtype: int64

# %%
data['Nautical_Twilight'].value_counts()
# Out:
# 0    2063472
# 1     779003
# 2       2867
# Name: Nautical_Twilight, dtype: int64

# %%
data1=data.head(1000)

# %%
benign_df=data1[data1['Nautical_Twilight']==0] 
maligant_df=data1[data1['Nautical_Twilight']==1]
help(benign_df.plot)
# Out:
# Help on PlotAccessor in module pandas.plotting._core object:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data)
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...

# %%
axes=benign_df.plot(kind='scatter',x='City',y='Start_Time',color='blue',label='Benign')
axes
# Out:
# <AxesSubplot:xlabel='City', ylabel='Start_Time'>

# %%
yxes=maligant_df.plot(kind='scatter',x='City',y='Start_Time',color='red',label='Benign')
yxes
# Out:
# <AxesSubplot:xlabel='City', ylabel='Start_Time'>

# %%
axes=benign_df.plot(kind='scatter',x='City',y='Start_Time',color='blue',label='Benign')
axes
yxes=maligant_df.plot(kind='scatter',x='City',y='Start_Time',color='red',label='Benign',ax=axes)
yxes
# Out:
# <AxesSubplot:xlabel='City', ylabel='Start_Time'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
feature_df=data[['Severity','End_Time','Start_Lat', 'End_Lng','Distance(mi)',
                  'Side','Number','Zipcode','Timezone','City','Temperature(F)','Pressure(in)',
                  'Wind_Direction','Wind_Speed(mph)','Junction','No_Exit','Traffic_Signal','Sunrise_Sunset',
                  'Civil_Twilight','Nautical_Twilight','Astronomical_Twilight']]

#cell of 100 row and 11 columns
# picked 9 columns out of 11

# independent variable
x=np.asarray(feature_df)

# dependent variable
y=np.asarray(data['Nautical_Twilight'])

x[0:5]
# Out:
# array([[ 3.0000000e+00,  0.0000000e+00,  7.8926900e+05, -8.3031870e+01,
#          3.2300000e+03,  2.0000000e+00,  4.6402000e+04,  1.8431200e+05,
#          1.0000000e+00,  2.8220000e+03,  3.6600000e+02,  9.2500000e+02,
#          1.6000000e+01,  1.8000000e+01,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  1.0000000e+00,  1.0000000e+00,  1.0000000e+00,
#          1.0000000e+00],
#        [ 2.0000000e+00,  1.0000000e+00,  7.6495700e+05, -8.4048730e+01,
#          7.4700000e+02,  2.0000000e+00,  4.6402000e+04,  1.8922400e+05,
#          1.0000000e+00,  2.5340000e+03,  3.3400000e+02,  9.1700000e+02,
#          1.0000000e+00,  1.3600000e+02,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  1.0000000e+00,  1.0000000e+00,  1.0000000e+00,
#          1.0000000e+00],
#        [ 2.0000000e+00,  2.0000000e+00,  7.1349300e+05, -8.4523960e+01,
#          5.5000000e+01,  2.0000000e+00,  4.6402000e+04,  1.8692500e+05,
# ...

# %%
data.isnull().sum()
# Out:
# ID                            0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                       0
# End_Lng                       0
# Distance(mi)                  0
# Description                   0
# Number                        0
# Street                        2
# Side                          0
# City                          0
# County                        0
# State                         0
# Zipcode                       0
# Country                       0
# Timezone                      0
# Airport_Code               9549
# Weather_Timestamp         50736
# Temperature(F)                0
# Wind_Chill(F)            469643
# Humidity(%)               73092
# Pressure(in)                  0
# Visibility(mi)            70546
# Wind_Direction                0
# Wind_Speed(mph)               0
# Precipitation(in)        549458
# ...

# %%
data.isnull().sum().sum()
# Out:
# 1223026

# %%
data.isna()
# Out:
#             ID  Severity  Start_Time  End_Time  Start_Lat  Start_Lng  End_Lat  \
# 0        False     False       False     False      False      False    False
# 1        False     False       False     False      False      False    False
# 2        False     False       False     False      False      False    False
# 3        False     False       False     False      False      False    False
# 4        False     False       False     False      False      False    False
# ...        ...       ...         ...       ...        ...        ...      ...
# 2845337  False     False       False     False      False      False    False
# 2845338  False     False       False     False      False      False    False
# 2845339  False     False       False     False      False      False    False
# 2845340  False     False       False     False      False      False    False
# 2845341  False     False       False     False      False      False    False
#
# ...

# %%
data.isnull().sum().sort_values()
# Out:
# ID                            0
# Wind_Direction                0
# Wind_Speed(mph)               0
# Weather_Condition             0
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# Pressure(in)                  0
# No_Exit                       0
# Roundabout                    0
# Station                       0
# Stop                          0
# Traffic_Calming               0
# Traffic_Signal                0
# Turning_Loop                  0
# Sunrise_Sunset                0
# Civil_Twilight                0
# Railway                       0
# Nautical_Twilight             0
# Astronomical_Twilight         0
# City                          0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                       0
# End_Lng                       0
# Distance(mi)                  0
# Description                   0
# ...

# %%
missing_percentage=data.isnull().sum().sort_values(ascending=False)/len(data)
missing_percentage
# Out:
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Humidity(%)              2.568830e-02
# Visibility(mi)           2.479350e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Street                   7.029032e-07
# Sunrise_Sunset           0.000000e+00
# Crossing                 0.000000e+00
# Wind_Speed(mph)          0.000000e+00
# Nautical_Twilight        0.000000e+00
# Civil_Twilight           0.000000e+00
# Weather_Condition        0.000000e+00
# Amenity                  0.000000e+00
# Bump                     0.000000e+00
# Give_Way                 0.000000e+00
# Turning_Loop             0.000000e+00
# Junction                 0.000000e+00
# Wind_Direction           0.000000e+00
# Railway                  0.000000e+00
# Roundabout               0.000000e+00
# Station                  0.000000e+00
# Stop                     0.000000e+00
# Traffic_Calming          0.000000e+00
# Traffic_Signal           0.000000e+00
# ...

# %%
type(missing_percentage)
# Out:
# pandas.core.series.Series

# %%
missing_percentage.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
missing_percentage!=0
# Out:
# Precipitation(in)         True
# Wind_Chill(F)             True
# Humidity(%)               True
# Visibility(mi)            True
# Weather_Timestamp         True
# Airport_Code              True
# Street                    True
# Sunrise_Sunset           False
# Crossing                 False
# Wind_Speed(mph)          False
# Nautical_Twilight        False
# Civil_Twilight           False
# Weather_Condition        False
# Amenity                  False
# Bump                     False
# Give_Way                 False
# Turning_Loop             False
# Junction                 False
# Wind_Direction           False
# Railway                  False
# Roundabout               False
# Station                  False
# Stop                     False
# Traffic_Calming          False
# Traffic_Signal           False
# No_Exit                  False
# ID                       False
# Pressure(in)             False
# Severity                 False
# Start_Time               False
# ...

# %%
#remove zero value
missing_percentage[missing_percentage!=0]
# Out:
# Precipitation(in)    1.931079e-01
# Wind_Chill(F)        1.650568e-01
# Humidity(%)          2.568830e-02
# Visibility(mi)       2.479350e-02
# Weather_Timestamp    1.783125e-02
# Airport_Code         3.356011e-03
# Street               7.029032e-07
# dtype: float64

# %%
missing_percentage[missing_percentage!=0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.City
# Out:
# 0               Dublin
# 1               Dayton
# 2           Cincinnati
# 3                Akron
# 4           Cincinnati
#               ...
# 2845337      Riverside
# 2845338      San Diego
# 2845339         Orange
# 2845340    Culver City
# 2845341       Highland
# Name: City, Length: 2845342, dtype: object

# %%
# unique city in city columns
citys=df.City.unique()
citys
# Out:
# array(['Dublin', 'Dayton', 'Cincinnati', ..., 'Clarksdale', 'Bridgeboro',
#        'American Fork-Pleasant Grove'], dtype=object)

# %%
len(citys)
# Out:
# 11682

# %%
citys[:100]
# Out:
# array(['Dublin', 'Dayton', 'Cincinnati', 'Akron', 'Williamsburg',
#        'Cleveland', 'Lima', 'Westerville', 'Jamestown', 'Freeport',
#        'Columbus', 'Toledo', 'Roanoke', 'Ft Mitchell', 'Edinburgh',
#        'Fairborn', 'Shelbyville', 'Greensburg', 'Saint Paul',
#        'Parkersburg', 'Indianapolis', 'Dundee', 'Jeffersonville',
#        'Pittsburgh', 'Lewis Center', 'Dunkirk', 'Redkey', 'Milton',
#        'Willshire', 'Straughn', 'Cambridge Springs', 'Fremont',
#        'Louisville', 'South Charleston', 'Edinboro', 'Buckhannon',
#        'Lockbourne', 'Painesville', 'Washington', 'Dunbar', 'Angola',
#        'Edon', 'Medina', 'De Mossville', 'New Albany', 'Charleston',
#        'Fort Wayne', 'Burnsville', 'Bedford', 'Clarksville', 'Lakewood',
#        'Richfield', 'Sewickley', 'Independence', 'Westlake', 'Erlanger',
#        'Grove City', 'Monroe', 'West Middlesex', 'Gaston', 'Economy',
#        'Fairmount', 'Hagerstown', 'Walton', 'Crittenden', 'Coraopolis',
# ...

# %%
citys_by_accident=df.City.value_counts()
citys_by_accident
# Out:
# Miami                           106966
# Los Angeles                      68956
# Orlando                          54691
# Dallas                           41979
# Houston                          39448
#                                  ...
# Ridgedale                            1
# Sekiu                                1
# Wooldridge                           1
# Bullock                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 11681, dtype: int64

# %%
#top city of number of accident
citys_by_accident[citys_by_accident>=1000]
# Out:
# Miami          106966
# Los Angeles     68956
# Orlando         54691
# Dallas          41979
# Houston         39448
#                 ...
# Tualatin         1001
# Utica            1001
# Los Banos        1001
# Mankato          1000
# Chiloquin        1000
# Name: City, Length: 496, dtype: int64

# %%
# among the top 100 city in number of accident, which state do they belong to most frequently  
top_city=(citys_by_accident[citys_by_accident>=1000]).head(10)
top_city
# Out:
# Miami          106966
# Los Angeles     68956
# Orlando         54691
# Dallas          41979
# Houston         39448
# Charlotte       33152
# Sacramento      32559
# San Diego       26627
# Raleigh         22840
# Minneapolis     22768
# Name: City, dtype: int64

# %%
citys_by_accident[:20]
# Out:
# Miami           106966
# Los Angeles      68956
# Orlando          54691
# Dallas           41979
# Houston          39448
# Charlotte        33152
# Sacramento       32559
# San Diego        26627
# Raleigh          22840
# Minneapolis      22768
# Portland         20944
# Nashville        20267
# Austin           18301
# Baton Rouge      18182
# Phoenix          17143
# Saint Paul       16869
# New Orleans      16251
# Atlanta          15622
# Jacksonville     14967
# Richmond         14349
# Name: City, dtype: int64

# %%
citys_by_accident[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
type(citys_by_accident)
# Out:
# pandas.core.series.Series

# %%
citys_by_accident[:15].plot(kind='barh')
plt.title('Total number of accidents by city from 2016-2021',size=17, color='black')
plt.xlabel('Number of Reported Accidents', fontsize=15, color='black')
plt.ylabel('City', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()

# %%
#new work is there or not
'new york' in df.City
# Out:
# False

# %%
df.State
# Out:
# 0          OH
# 1          OH
# 2          OH
# 3          OH
# 4          OH
#            ..
# 2845337    CA
# 2845338    CA
# 2845339    CA
# 2845340    CA
# 2845341    CA
# Name: State, Length: 2845342, dtype: object

# %%
'NY' in df.State
# Out:
# False

# %%
import seaborn as sns
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.set_style("darkgrid")

# %%
#most city less than 2000 accident
sns.distplot(citys_by_accident)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
high_accident_city=(citys_by_accident[citys_by_accident>=1000])
high_accident_city
# Out:
# Miami          106966
# Los Angeles     68956
# Orlando         54691
# Dallas          41979
# Houston         39448
#                 ...
# Tualatin         1001
# Utica            1001
# Los Banos        1001
# Mankato          1000
# Chiloquin        1000
# Name: City, Length: 496, dtype: int64

# %%
low_accident_city=(citys_by_accident[citys_by_accident < 1000])
low_accident_city
# Out:
# Osseo                           997
# Madras                          997
# Manor                           992
# Portsmouth                      988
# Schenectady                     985
#                                ...
# Ridgedale                         1
# Sekiu                             1
# Wooldridge                        1
# Bullock                           1
# American Fork-Pleasant Grove      1
# Name: City, Length: 11185, dtype: int64

# %%
len(high_accident_city)
# Out:
# 496

# %%
#less than 4% city more than 1000 accident
len(high_accident_city) /len(citys)
# Out:
# 0.04245848313644924

# %%
len(low_accident_city)
# Out:
# 11185

# %%
sns.distplot(high_accident_city)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
sns.distplot(low_accident_city)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
sns.histplot(citys_by_accident , log_scale=True)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
#city 1 accident
citys_by_accident[citys_by_accident==1]
# Out:
# Carney                          1
# Waverly Hall                    1
# Center Sandwich                 1
# Glen Flora                      1
# Sulphur Springs                 1
#                                ..
# Ridgedale                       1
# Sekiu                           1
# Wooldridge                      1
# Bullock                         1
# American Fork-Pleasant Grove    1
# Name: City, Length: 1110, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.Start_Time
# Out:
# 0          2016-02-08 00:37:08
# 1          2016-02-08 05:56:20
# 2          2016-02-08 06:15:39
# 3          2016-02-08 06:51:45
# 4          2016-02-08 07:53:43
#                   ...
# 2845337    2019-08-23 18:03:25
# 2845338    2019-08-23 19:11:30
# 2845339    2019-08-23 19:00:21
# 2845340    2019-08-23 19:00:21
# 2845341    2019-08-23 18:52:06
# Name: Start_Time, Length: 2845342, dtype: object

# %%
df.Start_Time[0]
# Out:
# '2016-02-08 00:37:08'

# %%
#convert string to date
df.Start_Time=pd.to_datetime(df.Start_Time)

# %%
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 00:37:08')

# %%
#pandas get hour for timespant(hour of the day)
df.Start_Time.dt.hour
# Out:
# 0           0
# 1           5
# 2           6
# 3           6
# 4           7
#            ..
# 2845337    18
# 2845338    19
# 2845339    19
# 2845340    19
# 2845341    18
# Name: Start_Time, Length: 2845342, dtype: int64

# %%
sns.histplot(df.Start_Time.dt.hour, bins=24, kde=True, stat="density", linewidth=0)  # By the day
# Out:
# <AxesSubplot:xlabel='Start_Time', ylabel='Density'>

# %%
Accident_Day = sum(df.Sunrise_Sunset == "Day")
Accident_Day  # More accidents during the day, which makes sense of course.
# Out:
# 1811935

# %%
day_twilight = sum((df.Nautical_Twilight == "Day") | (df.Civil_Twilight == "Day") | (df.Astronomical_Twilight== "Day"))
day_twilight  # 70 percent at day
# Out:
# 2179148

# %%
Accident_Night = sum(df.Sunrise_Sunset == "Night")
Accident_Night # 36 percent at night
# Out:
# 1030540

# %%
night_twilight = sum((df.Nautical_Twilight == "Night") | (df.Civil_Twilight == "Night") | (df.Astronomical_Twilight== "Night"))
night_twilight  # 30 percent at night
# Out:
# 915382

# %%
total = Accident_Day + Accident_Night
total
# Out:
# 2842475

# %%
total2 = day_twilight + night_twilight
total2
# Out:
# 3094530

# %%
sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
#this accident occure in the monday
monday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(monday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
# months (monday = day)
sns.distplot(df.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
yearly = pd.DataFrame(df.Start_Time.dt.year.value_counts()).reset_index().rename(columns={"index": "Year","Start_Time" :"Accident_Cases"})
yearly
# Out:
#    Year  Accident_Cases
# 0  2021         1511745
# 1  2020          625864
# 2  2019          258615
# 3  2017          163918
# 4  2018          163176
# 5  2016          122024

# %%
df_2019=df[df.Start_Time.dt.year==2019]
df_2019.head()
# Out:
#                 ID  Severity          Start_Time  \
# 582028    A-582029         4 2019-10-02 12:50:00
# 1295810  A-1295811         4 2019-11-01 16:18:00
# 1568027  A-1568028         4 2019-06-04 16:00:00
# 1756843  A-1756844         4 2019-10-19 04:30:00
# 1935372  A-1935373         4 2019-12-17 09:12:52
#
#                               End_Time  Start_Lat   Start_Lng    End_Lat  \
# 582028             2021-07-03 02:57:45  40.736515  -74.084907  40.736494
# 1295810            2021-03-28 23:55:52  29.955075  -90.071696  29.956304
# 1568027  2021-04-02 06:59:00.000000000  29.773556  -95.351304  29.773559
# 1756843  2020-11-01 00:00:00.000000000  38.875540  -77.280396  38.879090
# 1935372            2020-10-14 07:07:49  33.634089 -112.106196  33.636297
#
#             End_Lng  Distance(mi)  \
# 582028   -74.085300         0.021
# 1295810  -90.073488         0.137
# 1568027  -95.349689         0.097
# 1756843  -77.253206         1.483
# 1935372 -112.104149         0.193
#
# ...

# %%
 plt.figure(figsize=(10,6))
plt.title('Total number of accidents reported yearly from 2016-2021',size=17, color='black')
plt.xlabel('Year', fontsize=15, color='black')
plt.ylabel('Accident Cases', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

t = sns.barplot(x=yearly.Year, y = yearly.Accident_Cases)
plt.show()

# %%
#2019 sep and oct and dec accident 
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
df_2017=df[df.Start_Time.dt.year==2017]  
sns.distplot(df_2017.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
df_2016=df[df.Start_Time.dt.year==2016]  
sns.distplot(df_2016.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
states = df.State.value_counts()
states
# Out:
# CA    795868
# FL    401388
# TX    149037
# OR    126341
# VA    113535
# NY    108049
# PA     99975
# MN     97185
# NC     91362
# SC     89216
# MD     65085
# AZ     56504
# NJ     52902
# TN     52613
# UT     49193
# LA     47232
# IL     47105
# MI     43843
# GA     40086
# WA     32554
# CT     29762
# MO     29633
# CO     25340
# OH     24409
# IN     20850
# AL     19322
# MT     15964
# AR     10935
# IA      9607
# DC      9133
# KS      9033
# OK      8806
# ID      8544
# WI      7896
# WV      7632
# KY      6638
# MA      6392
# NV      6197
# MS      5320
# DE      4842
# RI      4451
# NH      3866
# NE      3320
# NM      2370
# ND      2258
# ME      2193
# WY       990
# VT       365
# SD       201
# Name: State, dtype: int64

# %%
states[:15].plot(kind='pie')
plt.title('Total number of accidents by state from 2016-2021',size=17, color='black')
plt.xlabel('Number of Reported Accidents', fontsize=15, color='black')
plt.ylabel('State', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Start_Lng", y="Start_Lat", hue="State", data=df, s=10, legend=False)
plt.xlabel("Longtiude")
plt.ylabel("Latitude")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,5))
sev = sns.countplot(x="Severity", data=df, palette = "cubehelix")
sev.set_title("Degree of Severity")
# Out:
# Text(0.5, 1.0, 'Degree of Severity')

# %%
df.Start_Lat
# Out:
# 0          40.108910
# 1          39.865420
# 2          39.102660
# 3          41.062130
# 4          39.172393
#              ...
# 2845337    34.002480
# 2845338    32.766960
# 2845339    33.775450
# 2845340    33.992460
# 2845341    34.133930
# Name: Start_Lat, Length: 2845342, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -83.092860
# 1          -84.062800
# 2          -84.524680
# 3          -81.537840
# 4          -84.492792
#               ...
# 2845337   -117.379360
# 2845338   -117.148060
# 2845339   -117.847790
# 2845340   -118.403020
# 2845341   -117.230920
# Name: Start_Lng, Length: 2845342, dtype: float64

# %%
sample_df = df.sample(int(0.1 * len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat, size=0.001)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>
